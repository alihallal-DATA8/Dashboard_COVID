# %%
# !ls
# Out:
# donnees-hospitalieres-classe-age-covid19-2021-02-18-19h03.csv  Untitled.ipynb
# requirement.txt

# %%
# !head donnees-hospitalieres-classe-age-covid19-2021-02-18-19h03.csv
# Out:
# "reg";"cl_age90";"jour";"hosp";"rea";"rad";"dc"
# "01";"0";2020-03-18;0;0;0;0
# "01";"09";2020-03-18;0;0;0;0
# "01";"19";2020-03-18;0;0;0;0
# "01";"29";2020-03-18;0;0;0;0
# "01";"39";2020-03-18;0;0;0;0
# "01";"49";2020-03-18;0;0;0;0
# "01";"59";2020-03-18;0;0;0;0
# "01";"69";2020-03-18;0;0;0;0
# "01";"79";2020-03-18;0;0;0;0

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_hosp = pd.read_csv('donnees-hospitalieres-classe-age-covid19-2021-02-18-19h03.csv', sep=';', parse_dates=['jour'] , 
                      index_col='jour')

# %%
df_hosp.head()
# Out:
#             reg  cl_age90  hosp  rea  rad  dc
# jour
# 2020-03-18    1         0     0    0    0   0
# 2020-03-18    1         9     0    0    0   0
# 2020-03-18    1        19     0    0    0   0
# 2020-03-18    1        29     0    0    0   0
# 2020-03-18    1        39     0    0    0   0

# %%
df_hosp.describe()
# Out:
#                 reg      cl_age90          hosp           rea           rad  \
# count  66924.000000  66924.000000  66924.000000  66924.000000  66924.000000
# mean      39.388889     48.272727    174.097857     23.514554   1091.267961
# std       32.287388     30.265991    584.668946     90.016893   3522.709819
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000     19.000000      2.000000      0.000000     29.000000
# 50%       30.000000     49.000000     11.000000      1.000000    166.000000
# 75%       75.000000     79.000000     93.000000     10.000000    725.000000
# max       94.000000     90.000000  13209.000000   2668.000000  64115.000000
#
#                  dc
# count  66924.000000
# mean     259.526523
# std      886.004682
# min        0.000000
# 25%        0.000000
# 50%        6.000000
# 75%      104.000000
# max    14356.000000

# %%
df_hosp.groupby([df_hosp.index,'reg','cl_age90']).sum().reset_index().set_index(['jour'])
# Out:
#             reg  cl_age90  hosp  rea  rad  dc
# jour
# 2020-03-18    1         0     0    0    0   0
# 2020-03-18    1         9     0    0    0   0
# 2020-03-18    1        19     0    0    0   0
# 2020-03-18    1        29     0    0    0   0
# 2020-03-18    1        39     0    0    0   0
# ...         ...       ...   ...  ...  ...  ..
# 2021-02-18   94        59     6    0   88   6
# 2021-02-18   94        69    13    4  110  15
# 2021-02-18   94        79    21    2  131  37
# 2021-02-18   94        89    34    1  119  55
# 2021-02-18   94        90    21    1   43  26
#
# [66924 rows x 6 columns]

# %%
import matplotlib.pyplot as plt 


df_hosp[df_hosp['dc'] ==df_hosp['dc'].max()]
# Out:
#             reg  cl_age90  hosp  rea    rad     dc
# jour
# 2021-02-18   11         0  4916  757  64115  14356

# %%
df_hosp[df_hosp.reg==77]
# Out:
# Empty DataFrame
# Columns: [reg, cl_age90, hosp, rea, rad, dc]
# Index: []

# %%
for cols in df_hosp.columns:
    print(cols, len(df_hosp[cols].unique()))
# Out:
# reg 18
# cl_age90 11
# hosp 2616
# rea 781
# rad 7001
# dc 3476

# %%
df_hosp
# Out:
#             reg  cl_age90  hosp  rea  rad  dc
# jour
# 2020-03-18    1         0     0    0    0   0
# 2020-03-18    1         9     0    0    0   0
# 2020-03-18    1        19     0    0    0   0
# 2020-03-18    1        29     0    0    0   0
# 2020-03-18    1        39     0    0    0   0
# ...         ...       ...   ...  ...  ...  ..
# 2021-02-18   94        59     6    0   88   6
# 2021-02-18   94        69    13    4  110  15
# 2021-02-18   94        79    21    2  131  37
# 2021-02-18   94        89    34    1  119  55
# 2021-02-18   94        90    21    1   43  26
#
# [66924 rows x 6 columns]

# %%
df_hosp[(df_hosp['cl_age90'] <= int(20))&(df_hosp['reg']==1)]
# Out:
#             reg  cl_age90  hosp  rea  rad   dc
# jour
# 2020-03-18    1         0     0    0    0    0
# 2020-03-18    1         9     0    0    0    0
# 2020-03-18    1        19     0    0    0    0
# 2020-03-19    1         0     0    0    0    0
# 2020-03-19    1         9     0    0    0    0
# ...         ...       ...   ...  ...  ...  ...
# 2021-02-17    1         9     0    0   21    0
# 2021-02-17    1        19     0    0    9    0
# 2021-02-18    1         0    31    5  826  175
# 2021-02-18    1         9     0    0   21    0
# 2021-02-18    1        19     0    0    9    0
#
# [1014 rows x 6 columns]

# %%
df_hosp.index
# Out:
# DatetimeIndex(['2020-03-18', '2020-03-18', '2020-03-18', '2020-03-18',
#                '2020-03-18', '2020-03-18', '2020-03-18', '2020-03-18',
#                '2020-03-18', '2020-03-18',
#                ...
#                '2021-02-18', '2021-02-18', '2021-02-18', '2021-02-18',
#                '2021-02-18', '2021-02-18', '2021-02-18', '2021-02-18',
#                '2021-02-18', '2021-02-18'],
#               dtype='datetime64[ns]', name='jour', length=66924, freq=None)

# %%
df_hosp.groupby([df_hosp.index,'reg','cl_age90']).hosp.sum()
# Out:
# jour        reg  cl_age90
# 2020-03-18  1    0            0
#                  9            0
#                  19           0
#                  29           0
#                  39           0
#                              ..
# 2021-02-18  94   59           6
#                  69          13
#                  79          21
#                  89          34
#                  90          21
# Name: hosp, Length: 66924, dtype: int64

# %%
def cumulative_sum(df, feature_name, by_reg= False):   
    '''return the cumulative sum of a column whose name is called  feature_name
    
    input:
    -----
    df: pandas Dataframe, rawdata 
    feature_name: str, name of a colomn in df, which is seperated data day by day
    
    return:
    -------
    cumulative sum of the feature_name by days regardless of age group
    
    '''
    if by_reg == True:
         return  pd.DataFrame(df.groupby(['reg',df.index]).sum().groupby('reg')[feature_name].cumsum()) 
    else:
        return pd.DataFrame(df.groupby([df.index,'reg']).sum().groupby('jour').sum()[feature_name].cumsum())

# %%
cumulative_sum(df_hosp, 'hosp', by_reg = False)
# Out:
#                 hosp
# jour
# 2020-03-18      5877
# 2020-03-19     14698
# 2020-03-20     25035
# 2020-03-21     37256
# 2020-03-22     51612
# ...              ...
# 2021-02-14  11443461
# 2021-02-15  11496221
# 2021-02-16  11548413
# 2021-02-17  11600078
# 2021-02-18  11651325
#
# [338 rows x 1 columns]

# %%
cumulative_sum(df_hosp, 'hosp', by_reg = True).loc[94, :].plot()
# Out:
# <AxesSubplot:xlabel='jour'>

# %%
cumulative_sum(df_hosp, 'hosp', by_reg = True)
# Out:
#                  hosp
# reg jour
# 1   2020-03-18      0
#     2020-03-19      0
#     2020-03-20      0
#     2020-03-21      0
#     2020-03-22     12
# ...               ...
# 94  2021-02-14  25079
#     2021-02-15  25182
#     2021-02-16  25281
#     2021-02-17  25374
#     2021-02-18  25564
#
# [6084 rows x 1 columns]

# %%
cumulative_sum(df_hosp, 'hosp', by_reg = False).plot()
# Out:
# <AxesSubplot:xlabel='jour'>
